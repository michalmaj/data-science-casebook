# %% [markdown]
# # Lesson 8 — Synthesis: Decision Note for Meridian Outlet
#
# Read `README.md` (or `README.pl.md`) first. This is the last lesson of Case 2 — the deliverable this time is not more code, it's the decision note below.

# %%
from task import final_scorecard, fit_classifier, load_and_merge_orders, split_orders

df = load_and_merge_orders()
train_df, test_df = split_orders(df)
model = fit_classifier(train_df)
final_scorecard(train_df, test_df, model)

# %% [markdown]
# ## Decision Note: Order Return Risk Analysis for Meridian Outlet
#
# Fill in each section below. Write in plain language — the ops manager reading this has not seen any of the code.

# %% [markdown]
# ### 1. Business question
#
# Meridian Outlet's original ask in Lesson 1 was vague ("too many orders get returned, tell us which ones are risky"). State the specific, measurable question this analysis actually answers.
#
# _Write your answer here._

# %% [markdown]
# ### 2. Approach
#
# In 2-3 sentences: what data did you use, how did you clean and merge it, what model did you build, and how did you validate it?
#
# _Write your answer here._

# %% [markdown]
# ### 3. Results
#
# Using the scorecard table above: state how the model performs at the default 0.5 threshold compared to the majority baseline, and how much better it does once you move to the chosen 0.2 threshold.
#
# _Write your answer here._

# %% [markdown]
# ### 4. Threshold and metric choice
#
# Lesson 6 showed that lowering the threshold trades precision for recall. Explain, in terms Meridian Outlet would understand, why 0.2 was chosen over 0.5 — and what that choice costs in false alarms.
#
# _Write your answer here._

# %% [markdown]
# ### 5. Communicating risk
#
# Lesson 7 built risk tiers (Low/Medium/High) and found the High tier's observed return rate wasn't reliably higher than Medium's in a small test set. Explain what that means for how confidently Meridian Outlet should treat these tiers.
#
# _Write your answer here._

# %% [markdown]
# ### 6. Limitations
#
# List at least two honest limitations of this analysis.
#
# _Write your answer here._

# %% [markdown]
# ### 7. Recommendation
#
# Give Meridian Outlet one concrete recommendation they could act on this week, grounded in the findings above — not a generic "collect more data."
#
# _Write your answer here._
