# %% [markdown]
# # Lesson 1 — Defining the Question
#
# Read `README.md` (or `README.pl.md`) first — it has Meridian Outlet's ask and the mentor's framing. This notebook is your first look at their data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from task import list_sheet_names

list_sheet_names()

# %% [markdown]
# ## First look at Orders
#
# This file has two sheets. Start with the one that has our target variable.

# %%
from task import load_raw_orders_sheet

df = load_raw_orders_sheet()
df.head()

# %% [markdown]
# ## Something's wrong here
#
# Look at the column names and the first row. This file was built for a human reading a spreadsheet, not for pandas. We'll fix this properly in Lesson 2 — for now, just look.

# %%
df.columns.tolist(), df.shape

# %% [markdown]
# ## Even so, we can still find our target
#
# The business question survives the messy load.

# %%
from task import target_column_name

target_column_name()

# %% [markdown]
# ## Your notes
#
# What exactly is wrong with this raw load? Write down what you think you'd need to do to fix it — but don't fix it yet, that's Lesson 2.
