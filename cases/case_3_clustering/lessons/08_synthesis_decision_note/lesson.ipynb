# %% [markdown]
# # Lesson 8 — Synthesis: Decision Note for Aurora Stream
#
# Read `README.md` (or `README.pl.md`) first. This is the last lesson of Case 3 — the deliverable this time is not more code, it's the decision note below.

# %%
from task import final_segment_table, load_scaled_features

df = load_scaled_features()
final_segment_table(df)

# %% [markdown]
# ## Decision Note: Subscriber Segmentation for Aurora Stream
#
# Fill in each section below. Write in plain language — the stakeholder reading this has not seen any of the code.

# %% [markdown]
# ### 1. Business question
#
# Aurora Stream's original ask in Lesson 1 was to understand what kinds of subscribers they actually have, so retention offers could be tailored instead of one-size-fits-all. State the specific, measurable question this analysis actually answers.
#
# _Write your answer here._

# %% [markdown]
# ### 2. Approach
#
# In 2-3 sentences: what data did you use, how did you extract and scale it, what model did you build, and how did you decide on the number of segments?
#
# _Write your answer here._

# %% [markdown]
# ### 3. Results
#
# Using the table above: how many segments are there, how big is each one, and what separates them?
#
# _Write your answer here._

# %% [markdown]
# ### 4. Choosing k and checking stability
#
# Lesson 5 found that inertia and silhouette score didn't agree on a single "best" k. Lesson 7 found the k=2 solution was perfectly stable under resampling, while k=4 was not. Explain, in terms Aurora Stream would understand, why k=2 was the segmentation actually used here.
#
# _Write your answer here._

# %% [markdown]
# ### 5. Interpreting the segments
#
# Lesson 6 found the two segments differ almost entirely on viewing engagement, not tenure, plan tier, or country. Name each segment and describe, in plain language, who is in it.
#
# _Write your answer here._

# %% [markdown]
# ### 6. Limitations
#
# List at least two honest limitations of this analysis.
#
# _Write your answer here._

# %% [markdown]
# ### 7. Recommendation
#
# Give Aurora Stream one concrete recommendation they could act on this week for each segment, grounded in the findings above — not a generic "collect more data."
#
# _Write your answer here._
