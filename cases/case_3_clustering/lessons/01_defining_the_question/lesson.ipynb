# %% [markdown]
# # Lesson 1 — Defining the Question
#
# Read `README.md` (or `README.pl.md`) first — it has Aurora Stream's ask. New case, new format: SQLite this time, no messy Excel tricks, just real SQL.

# %%
from task import list_tables

list_tables()

# %% [markdown]
# ## Build the table you'll actually work from
#
# Two normalized tables become one per-subscriber table via a SQL join and aggregation.

# %%
from task import load_subscriber_features

df = load_subscriber_features()
df.shape, df.columns.tolist()

# %% [markdown]
# ## Not every subscriber has a session
#
# Look at what a LEFT JOIN does for subscribers with no matching rows.

# %%
df[df["session_count"] == 0]

# %% [markdown]
# ## Your notes
#
# Two subscribers have zero sessions. Are they a "ghost" segment, or should they be excluded from the analysis entirely? Write down your call and why.
