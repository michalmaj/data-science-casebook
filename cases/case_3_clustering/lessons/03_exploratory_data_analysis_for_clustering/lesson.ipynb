# %% [markdown]
# # Lesson 3 — Exploratory Data Analysis for Clustering
#
# Read `README.md` (or `README.pl.md`) first — it has Aurora Stream's framing for today. No target column this time — just look for structure among the features themselves.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from task import load_scaled_features

df = load_scaled_features()
df.shape

# %% [markdown]
# ## No target to check against
#
# Unlike Cases 1-2, there's no label to correlate features with. Look at how the features relate to each other instead.

# %%
from task import feature_correlations

corr = feature_correlations(df)
corr

# %% [markdown]
# ## Some of these features overlap almost completely
#
# Check tenure_days specifically — how does it compare to the other three?

# %%
corr["tenure_days"]

# %% [markdown]
# ## Your notes
#
# Three features correlate above 0.9 with each other. One sentence: what does that suggest about how many genuinely different signals you actually have?
