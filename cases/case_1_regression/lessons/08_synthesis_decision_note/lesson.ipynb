# %% [markdown]
# # Lesson 8 — Synthesis: Decision Note for TransLine
#
# Read `README.md` (or `README.pl.md`) first. This is the last lesson of Case 1 — the deliverable this time is not more code, it's the decision note below. Run the cell after this one to get the numbers, then write the note using what you've learned in Lessons 1-7.

# %%
from task import final_scorecard, fit_model, load_clean_shipments, split_shipments

df = load_clean_shipments()
train_df, test_df = split_shipments(df)
model = fit_model(train_df)
final_scorecard(train_df, test_df, model)

# %% [markdown]
# ## Decision Note: Shipment Delay Analysis for TransLine Logistics
#
# Fill in each section below. Write in plain language — the ops manager reading this has not seen any of the code.

# %% [markdown]
# ### 1. Business question
#
# TransLine's original ask in Lesson 1 was vague ("shipments are late, fix it"). State the specific, measurable question this analysis actually answers.
#
# _Write your answer here._

# %% [markdown]
# ### 2. Approach
#
# In 2-3 sentences: what data did you use, how did you clean it, what model did you build, and how did you validate it?
#
# _Write your answer here._

# %% [markdown]
# ### 3. Results
#
# Using the scorecard table above: state the model's MAE on held-out data, and how much of an improvement that is over TransLine's best naive guess (the mean-baseline).
#
# _Write your answer here._

# %% [markdown]
# ### 4. What the model misses
#
# Lesson 6 found a systematic blind spot in this model. Name it, and give a rough sense of how large the error is for the affected shipments.
#
# _Write your answer here._

# %% [markdown]
# ### 5. What's actually actionable
#
# Lesson 7 distinguished correlation, prediction, and causation. Which factors in this analysis can TransLine plausibly act on, and which should they not build a causal story around?
#
# _Write your answer here._

# %% [markdown]
# ### 6. Limitations
#
# List at least two honest limitations of this analysis.
#
# _Write your answer here._

# %% [markdown]
# ### 7. Recommendation
#
# Give TransLine one concrete recommendation they could act on this week, grounded in the findings above — not a generic "collect more data."
#
# _Write your answer here._
