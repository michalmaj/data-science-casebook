# %% [markdown]
# # Lesson 1 — Defining the Question
#
# Read `README.md` (or `README.pl.md`) before starting this notebook — it has the client's ask and the mentor's framing. This notebook is where you turn that ask into a first look at the data.

# %%
from task import load_shipments, target_column_name, missing_value_counts

df = load_shipments()
df.head()

# %% [markdown]
# ## First look
#
# Use `describe()` to see the shape of each numeric column.

# %%
df.describe()

# %% [markdown]
# ## Target variable
#
# Which column answers TransLine's question — "how late will this shipment be?"

# %%
target_column_name()

# %% [markdown]
# ## Data quality: missing values
#
# Before trusting any of these columns, check what's missing.

# %%
missing_value_counts(df)

# %% [markdown]
# ## Your notes
#
# Write down: which columns look trustworthy, which don't, and what you'd ask the client before going further.
