# %% [markdown]
# # Capstone Lesson 3 — Exploration
#
# Read `README.md` (or `README.pl.md`) first. Load the same dataset you picked in Lesson 1 — set DATASET_NAME below to match.

# %%
from task import load_clean_dataset

DATASET_NAME = "clinic_wait_times"  # change to the dataset you picked in Lesson 1
df = load_clean_dataset(DATASET_NAME)
df.shape

# %% [markdown]
# ## How do the numeric features relate to each other?
#
# `numeric_correlations` picks out only the numeric columns automatically and computes their pairwise correlation.

# %%
from task import numeric_correlations

corr = numeric_correlations(df)
corr

# %% [markdown]
# ## Which relationships stand out?
#
# Look for the strongest correlations in the table above — both the highest positive and the lowest (most negative) values.

# %%
corr.unstack().sort_values(ascending=False).drop_duplicates()

# %% [markdown]
# ## Your notes
#
# One sentence: which feature(s) look most worth paying attention to for your analytical question from Lesson 1, and which look like they might not matter much? Why?
#
# _Write your answer here._
