# %% [markdown]
# # Capstone Lesson 2 — Data Preparation
#
# Read `README.md` (or `README.pl.md`) first. Load the same dataset you picked in Lesson 1 — set DATASET_NAME below to match.

# %%
from task import load_dataset

DATASET_NAME = "clinic_wait_times"  # change to the dataset you picked in Lesson 1
df = load_dataset(DATASET_NAME)
df.shape

# %% [markdown]
# ## Before cleaning
#
# Check which columns actually have gaps, and how many.

# %%
from task import missing_value_counts

missing_value_counts(df)

# %% [markdown]
# ## Cleaning strategy
#
# `clean_dataset` fills numeric columns with their median and non-numeric columns with their most common value (the mode). Run it and confirm nothing is missing afterward.

# %%
from task import clean_dataset

cleaned = clean_dataset(df)
missing_value_counts(cleaned)

# %% [markdown]
# ## Your notes
#
# One sentence: for the columns that had gaps in your dataset, is median/mode filling a reasonable choice, or would you have handled it differently? Why?
#
# _Write your answer here._

# %% [markdown]
# ## Reflection
#
# The mentor asks: filling a gap with the median or mode is a real decision, not a neutral default — it assumes the missing values aren't systematically different from the ones you do have. What would make that assumption wrong for your dataset?
#
# _Write your answer here._
