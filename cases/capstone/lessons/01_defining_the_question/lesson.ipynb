# %% [markdown]
# # Capstone Lesson 1 — Defining the Question
#
# Read `README.md` (or `README.pl.md`) first — it has the menu of three client engagements. Pick one, load it, and write your own analytical question below.

# %%
from task import list_datasets

list_datasets()

# %% [markdown]
# ## Pick your client
#
# Read the three briefs in `README.md`. Once you've picked one, set DATASET_NAME below to its name and run the next cells.

# %%
from task import load_dataset

DATASET_NAME = "clinic_wait_times"  # change to the dataset you picked
df = load_dataset(DATASET_NAME)
df.shape

# %%
df.head()

# %%
from task import missing_value_counts

missing_value_counts(df)

# %% [markdown]
# ## Your notes
#
# Write your answer to today's analytical question: what specific, measurable question will you answer for your chosen client? What's your target variable? What's your success metric?
#
# _Write your answer here._

# %% [markdown]
# ## Reflection
#
# The mentor asks: it's easy to pick a question that sounds interesting but that this data can't actually answer. Looking at the columns you just printed, is there anything about your question that the data might not be able to support?
#
# _Write your answer here._
